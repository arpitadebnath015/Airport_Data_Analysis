# %%
pip install dash sqlalchemy pymysql pandas plotly
# Out:
# ...
#      ---------------------------------------- 7.9/7.9 MB 4.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# Database Credentials
db_user='root'
db_password='1234'
db_host='localhost'
db_name='sample_airport_db'

# Create Connection Engine
engine= create_engine(f'mysql+pymysql://{db_user}:{db_password}@{db_host}/{db_name}')

# Query Data
query= "select * from airport_db"
df= pd.read_sql(query,engine)
df.head()
# Out:
#   Origin_airport Destination_airport    Origin_city Destination_city  \
# 0            MHK                 AMW  Manhattan, KS         Ames, IA
# 1            EUG                 RDM     Eugene, OR         Bend, OR
# 2            EUG                 RDM     Eugene, OR         Bend, OR
# 3            EUG                 RDM     Eugene, OR         Bend, OR
# 4            MFR                 RDM    Medford, OR         Bend, OR
#
#    Passengers  Seats  Flights  Distance    Fly_date  Origin_population  \
# 0          21     30        1       254  2008-10-01             122049
# 1          41    396       22       103  1990-11-01             284093
# 2          88    342       19       103  1990-12-01             284093
# 3          11     72        4       103  1990-10-01             284093
# 4           0     18        1       156  1990-02-01             147300
#
#    Destination_population  Org_airport_lat  Org_airport_long Dest_airport_lat  \
# ...

# %%
# Create Simple Dash Application

from dash import Dash,dcc,html
import plotly.express as px

# Create Dash App
app= Dash(__name__)

# Plot using Plotly(Passengers data over distance)
fig= px.scatter(df, x='Distance', y='Passengers', color='Origin_airport',title='Passengers Vs Distance', labels={'Passengers':'Passengers','Distance':'Distance(Miles)'})

app.layout= html.Div(children=[
    html.H1(children='Flight Dashboard'),
    dcc.Graph(
        id='Passenger-Distance_Graph',
        figure= fig
    ),
    html.Div(children='Dashboard for visualisation of flight data')
])

if __name__=='__main__':
    app.run_server(debug=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12244\1514992739.py in <module>
#       1 # Create Simple Dash Application
#       2
# ----> 3 from dash import Dash,dcc,html
#       4 import plotly.express as px
#       5
#
# ~\anaconda3\lib\site-packages\dash\__init__.py in <module>
#      42 from ._jupyter import jupyter_dash  # noqa: F401,E402
#      43
# ---> 44 from ._hooks import hooks  # noqa: F401,E402
#      45
#      46 ctx = callback_context
#
# ~\anaconda3\lib\site-packages\dash\_hooks.py in <module>
#      22
#      23
# ---> 24 HookDataType = _tx.TypeVar("HookDataType")
#      25
#      26
#
# AttributeError: module 'typing_extensions' has no attribute 'TypeVar'
